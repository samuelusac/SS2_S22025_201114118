# %%
from sqlalchemy import create_engine, text
import contextlib, pymysql, os, urllib.request
import pandas as pd

# %%
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/Vallit0/SS2_EVD2025/main/clase5/"
COMPRAS_URL = DOWNLOAD_ROOT + "compras.csv"
VENTAS_URL = DOWNLOAD_ROOT + "ventas.csv"

COMPRAS_PATH = os.path.join("crudos", "compras")
VENTAS_PATH = os.path.join("crudos", "ventas")

def descargar_csv(url, destino, nombre):
    os.makedirs(destino, exist_ok=True)
    path_final = os.path.join(destino, nombre)
    urllib.request.urlretrieve(url, path_final)
    print(f"{nombre} descargado exitosamente")

def descargar_sql(url, destino, nombre):
    os.makedirs(destino, exist_ok=True)
    path_final = os.path.join(destino, nombre)
    urllib.request.urlretrieve(url, path_final)
    print(f"{nombre} SQL Descargado")

descargar_csv(COMPRAS_URL, COMPRAS_PATH, "compras.csv")
descargar_csv(VENTAS_URL, VENTAS_PATH, "ventas.csv")
# Out:
# compras.csv descargado exitosamente
# ventas.csv descargado exitosamente

# %%
compras = pd.read_csv(os.path.join(COMPRAS_PATH, "compras.csv"))
ventas  = pd.read_csv(os.path.join(VENTAS_PATH,  "ventas.csv"))

ventas
# Out:
#           Fecha CodCliente                 NombreCliente TipoCliente  \
# 0    13/07/2021      C0100  Iván Gonzalo Barreto Ordóñez   Mayorista
# 1    21/03/2022      C0100  Iván Gonzalo Barreto Ordóñez   Mayorista
# 2    01/11/2020      C0100  Iván Gonzalo Barreto Ordóñez   Mayorista
# 3    17/07/2023      C0100  Iván Gonzalo Barreto Ordóñez   Mayorista
# 4    23/12/2018      C0100  Iván Gonzalo Barreto Ordóñez   Mayorista
# ..          ...        ...                           ...         ...
# 995  14/02/2019     C0039              Wilfrido Casillas   Minorista
# 996  24/03/2024     C0035   Anel Ricardo Palomino Montes   Minorista
# 997  24/04/2024     C0014          Dr. Carolina Arguello   Mayorista
# 998  07/11/2021     C0012         Alfonso Urrutia Tafoya   Mayorista
# 999  03/02/2024     C0010                   Sara Guevara   Mayorista
#
#     CodVendedor           NombreVendedor CodProducto           NombreProducto  \
# 0         V0008        Mtro. Hugo Ruelas     AC00004         Vino Gato Blanco
# 1         V0007           Eugenio Correa     AC00004         Vino Gato Blanco
# 2         V0003         Serafín Carvajal     AC00003          Queso Camembert
# 3         V0008        Mtro. Hugo Ruelas     AC00001     Gaseosa Postobon Uva
# 4         V0007           Eugenio Correa     AC00006   Vino espumoso Rothberg
# ..          ...                      ...         ...                      ...
# 995       V0009   Reynaldo Mejía Guevara     AC00003          Queso Camembert
# 996       V0003         Serafín Carvajal     AC00002  Cerveza Hofbrau Munchen
# 997       V0006  Ing. Adalberto Iglesias     AC00002  Cerveza Hofbrau Munchen
# 998       V0003         Serafín Carvajal     AC00003          Queso Camembert
# 999       V0001           Renato de León     AC00005  Servilletas Familia Max
#
#     MarcaProducto           Categoria CodSucursal  NombreSucursal  \
# 0     CREM HELADO     Vinos y Licores       S0004  Sucursal Oeste
# 1     CREM HELADO     Vinos y Licores       S0003   Sucursal Este
# 2      MONTICELLO         Charcutería       S0002    Sucursal Sur
# 3        POSTOBON             Bebidas       S0002    Sucursal Sur
# 4        SINFONIA     Vinos y Licores       S0003   Sucursal Este
# ..            ...                 ...         ...             ...
# 995    MONTICELLO         Charcutería       S0002    Sucursal Sur
# 996          ZENU     Vinos y Licores       S0001  Sucursal Norte
# 997          ZENU     Vinos y Licores       S0001  Sucursal Norte
# 998    MONTICELLO         Charcutería       S0004  Sucursal Oeste
# 999         ZORBA  Limpieza de cocina       S0003   Sucursal Este
#
#             Region    Departamento  Unidades  PrecioUnitario
# 0        Occidente   Huehuetenango       294         1104.71
# 1       Nororiente          Zacapa        31          398.48
# 2     Suroccidente  Quetzaltenango       277          183.63
# 3     Suroccidente  Quetzaltenango       365          647.15
# 4       Nororiente          Zacapa       446          944.95
# ..             ...             ...       ...             ...
# 995   Suroccidente  Quetzaltenango        58          570.71
# 996  Metropolitana       Guatemala       274          368.75
# 997  Metropolitana       Guatemala       206          986.18
# 998      Occidente   Huehuetenango       203          260.53
# 999     Nororiente          Zacapa       497          718.64
#
# [1000 rows x 16 columns]

# %%
# Dimension fecha

fechas_unicas = pd.concat([compras["Fecha"], ventas["Fecha"]], ignore_index=True).dropna().drop_duplicates()

dim_fecha = pd.DataFrame({"Fecha": fechas_unicas})
nan_rows = dim_fecha[dim_fecha.isna().any(axis=1)]
dim_fecha["Fecha"] = pd.to_datetime(dim_fecha["Fecha"], format='%d/%m/%Y', errors = 'coerce')
dim_fecha["id_fecha"] = dim_fecha["Fecha"].dt.strftime("%Y%m%d").astype(int, errors = 'ignore')
dim_fecha["anio"] = dim_fecha["Fecha"].dt.year
dim_fecha["mes"] = dim_fecha["Fecha"].dt.month
dim_fecha["dia"] = dim_fecha["Fecha"].dt.day
mes_nombres = {
    1:"Enero", 2:"Febrero", 3:"Marzo", 4:"Abril",
    5:"Mayo",  6:"Junio",   7:"Julio", 8:"Agosto",
    9:"Septiembre", 10:"Octubre", 11:"Noviembre", 12:"Diciembre"
}
dim_fecha["nombre_mes"] = dim_fecha["mes"].map(mes_nombres)
dim_fecha["trimestre"] = "T" + (((dim_fecha["mes"] - 1) // 3) + 1).astype(str)
dim_fecha = dim_fecha[["id_fecha", "anio", "nombre_mes", "trimestre", "dia", "mes"]]
dim_fecha
# Out:
#       id_fecha    anio  nombre_mes trimestre   dia   mes
# 0     20191111  2019.0   Noviembre      T4.0  11.0  11.0
# 1     20221208  2022.0   Diciembre      T4.0   8.0  12.0
# 2     20221028  2022.0     Octubre      T4.0  28.0  10.0
# 3     20180708  2018.0       Julio      T3.0   8.0   7.0
# 4     20200816  2020.0      Agosto      T3.0  16.0   8.0
# ...        ...     ...         ...       ...   ...   ...
# 1990  20210918  2021.0  Septiembre      T3.0  18.0   9.0
# 1991  20230928  2023.0  Septiembre      T3.0  28.0   9.0
# 1993  20211027  2021.0     Octubre      T4.0  27.0  10.0
# 1994  20231104  2023.0   Noviembre      T4.0   4.0  11.0
# 1995  20190214  2019.0     Febrero      T1.0  14.0   2.0
#
# [1394 rows x 6 columns]

# %%
# Definicion de credenciales de base de datos

DB_USER = 'dba'
DB_PASSWORD = 'Ss2_USAC2025#'
DB_HOST = 'localhost'
DB_PORT = '3306'
DB_NAME = 'mysql'

connection_string = (
    f"mysql+pymysql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

# %%
# DDL

sql_script_drop_db = """
DROP DATABASE DWH;
"""

sql_script_create_db = """
CREATE DATABASE IF NOT EXISTS DWH;
"""

sql_script_create_table_dim_fecha = """
CREATE TABLE DWH.dim_fecha (
    id_fecha    INT PRIMARY KEY,
    anio        INT NOT NULL,
    nombre_mes  NVARCHAR(20),
    trimestre   NVARCHAR(20),
    dia         INT NOT NULL,
    mes         INT NOT NULL
);
"""

sql_script_create_table_dim_producto= """
CREATE TABLE DWH.dim_producto (
    CodProducto     NVARCHAR(50) PRIMARY KEY,
    NombreProducto  NVARCHAR(200),
    MarcaProducto   NVARCHAR(100),
    Categoria       NVARCHAR(100)
);
"""

sql_script_create_table_dim_sucursal= """
CREATE TABLE DWH.dim_sucursal (
    CodSucursal     NVARCHAR(50) PRIMARY KEY,
    NombreSucursal  NVARCHAR(200),
    Region          NVARCHAR(100),
    Departamento    NVARCHAR(100)
);
"""

sql_script_create_table_dim_cliente= """
CREATE TABLE DWH.dim_cliente (
    CodCliente      NVARCHAR(50) PRIMARY KEY,
    NombreCliente   NVARCHAR(200),
    TipoCliente     NVARCHAR(100)
);
"""

sql_script_create_table_dim_vendedor= """
CREATE TABLE DWH.dim_vendedor (
    CodVendedor     NVARCHAR(50) PRIMARY KEY,
    NombreVendedor  NVARCHAR(200)
);
"""

sql_script_create_table_dim_proveedor= """
CREATE TABLE DWH.dim_proveedor (
    CodProveedor    NVARCHAR(50) PRIMARY KEY,
    NombreProveedor NVARCHAR(200)
);
"""

sql_script_create_table_fac_ventas= """
CREATE TABLE DWH.fac_ventas (
    id_venta        INT AUTO_INCREMENT PRIMARY KEY,
    id_fecha        INT NOT NULL,
    CodProducto     NVARCHAR(50) NOT NULL,
    CodSucursal     NVARCHAR(50) NOT NULL,
    CodCliente      NVARCHAR(50) NOT NULL,
    CodVendedor     NVARCHAR(50) NOT NULL,
    unidades        INT NOT NULL,
    precioUnitario  DECIMAL(10,2)
);
"""
sql_script_create_table_fac_compras= """
CREATE TABLE DWH.fac_compras (
    id_compra       INT AUTO_INCREMENT PRIMARY KEY,
    id_fecha        INT NOT NULL,
    CodProducto     NVARCHAR(50) NOT NULL,
    CodSucursal     NVARCHAR(50) NOT NULL,
    CodProveedor    NVARCHAR(50) NOT NULL,
    unidades        INT NOT NULL,
    costoUnitario   DECIMAL(10,2),
    FOREIGN KEY (id_fecha)     REFERENCES dim_fecha(id_fecha),
    FOREIGN KEY (CodProducto)  REFERENCES dim_producto(CodProducto),
    FOREIGN KEY (CodSucursal)  REFERENCES dim_sucursal(CodSucursal),
    FOREIGN KEY (CodProveedor) REFERENCES dim_proveedor(CodProveedor)
);
"""

# %%
engine = create_engine(connection_string, echo=True)
print(f"Engine created: {engine}")

try:
    with engine.connect() as connection:
        connection.execute(text(sql_script_drop_db))
        connection.commit();
        print("Base de datos eliminada.")
        connection.execute(text(sql_script_create_db))
        connection.commit();
        print("Base de datos creada.")
        connection.execute(text(sql_script_create_table_dim_fecha))
        connection.execute(text(sql_script_create_table_dim_producto))
        connection.execute(text(sql_script_create_table_dim_sucursal))
        connection.execute(text(sql_script_create_table_dim_cliente))
        connection.execute(text(sql_script_create_table_dim_vendedor))
        connection.execute(text(sql_script_create_table_dim_proveedor))
        connection.execute(text(sql_script_create_table_fac_ventas))
        connection.execute(text(sql_script_create_table_fac_compras))
        connection.commit();
        dim_fecha.to_sql(
            name = 'DWH.dim_fecha',
            con = connection,
            if_exist = 'replace',
            index = False
        )
        connection.commit();
    print("DDL ejecutado correctamente.")
except Exception as e:
    print(f"Error al ejecutar DDL: {e}")
# Out:
# Engine created: Engine(mysql+pymysql://dba:***@localhost:3306/mysql)
# 2025-12-12 16:54:40,172 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-12-12 16:54:40,173 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-12 16:54:40,178 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-12-12 16:54:40,179 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-12 16:54:40,181 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-12-12 16:54:40,184 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-12 16:54:40,188 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-12 16:54:40,191 INFO sqlalchemy.engine.Engine
# DROP DATABASE DWH;
#
# 2025-12-12 16:54:40,193 INFO sqlalchemy.engine.Engine [generated in 0.00434s] {}
# 2025-12-12 16:54:40,246 INFO sqlalchemy.engine.Engine COMMIT
# Base de datos eliminada.
# 2025-12-12 16:54:40,256 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-12 16:54:40,266 INFO sqlalchemy.engine.Engine
# CREATE DATABASE IF NOT EXISTS DWH;
#
# 2025-12-12 16:54:40,270 INFO sqlalchemy.engine.Engine [generated in 0.01332s] {}
# 2025-12-12 16:54:40,301 INFO sqlalchemy.engine.Engine COMMIT
# Base de datos creada.
# 2025-12-12 16:54:40,303 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-12 16:54:40,305 INFO sqlalchemy.engine.Engine
# CREATE TABLE DWH.dim_fecha (
#     id_fecha    INT PRIMARY KEY,
#     anio        INT NOT NULL,
#     nombre_mes  NVARCHAR(20),
#     trimestre   NVARCHAR(20),
#     dia         INT NOT NULL,
#     mes         INT NOT NULL
# );
#
# 2025-12-12 16:54:40,309 INFO sqlalchemy.engine.Engine [generated in 0.00609s] {}
# 2025-12-12 16:54:40,375 INFO sqlalchemy.engine.Engine
# CREATE TABLE DWH.dim_producto (
#     CodProducto     NVARCHAR(50) PRIMARY KEY,
#     NombreProducto  NVARCHAR(200),
#     MarcaProducto   NVARCHAR(100),
#     Categoria       NVARCHAR(100)
# );
#
# 2025-12-12 16:54:40,377 INFO sqlalchemy.engine.Engine [generated in 0.00188s] {}
# 2025-12-12 16:54:40,440 INFO sqlalchemy.engine.Engine
# CREATE TABLE DWH.dim_sucursal (
#     CodSucursal     NVARCHAR(50) PRIMARY KEY,
#     NombreSucursal  NVARCHAR(200),
#     Region          NVARCHAR(100),
#     Departamento    NVARCHAR(100)
# );
#
# 2025-12-12 16:54:40,448 INFO sqlalchemy.engine.Engine [generated in 0.00188s] {}
# 2025-12-12 16:54:40,507 INFO sqlalchemy.engine.Engine
# CREATE TABLE DWH.dim_cliente (
#     CodCliente      NVARCHAR(50) PRIMARY KEY,
#     NombreCliente   NVARCHAR(200),
#     TipoCliente     NVARCHAR(100)
# );
#
# 2025-12-12 16:54:40,510 INFO sqlalchemy.engine.Engine [generated in 0.00222s] {}
# 2025-12-12 16:54:40,572 INFO sqlalchemy.engine.Engine
# CREATE TABLE DWH.dim_vendedor (
#     CodVendedor     NVARCHAR(50) PRIMARY KEY,
#     NombreVendedor  NVARCHAR(200)
# );
#
# 2025-12-12 16:54:40,574 INFO sqlalchemy.engine.Engine [generated in 0.00212s] {}
# 2025-12-12 16:54:40,621 INFO sqlalchemy.engine.Engine
# CREATE TABLE DWH.dim_proveedor (
#     CodProveedor    NVARCHAR(50) PRIMARY KEY,
#     NombreProveedor NVARCHAR(200)
# );
#
# 2025-12-12 16:54:40,623 INFO sqlalchemy.engine.Engine [generated in 0.00190s] {}
# 2025-12-12 16:54:40,670 INFO sqlalchemy.engine.Engine
# CREATE TABLE DWH.fac_ventas (
#     id_venta        INT AUTO_INCREMENT PRIMARY KEY,
#     id_fecha        INT NOT NULL,
#     CodProducto     NVARCHAR(50) NOT NULL,
#     CodSucursal     NVARCHAR(50) NOT NULL,
#     CodCliente      NVARCHAR(50) NOT NULL,
#     CodVendedor     NVARCHAR(50) NOT NULL,
#     unidades        INT NOT NULL,
#     precioUnitario  DECIMAL(10,2)
# );
#
# 2025-12-12 16:54:40,673 INFO sqlalchemy.engine.Engine [generated in 0.00386s] {}
# 2025-12-12 16:54:40,746 INFO sqlalchemy.engine.Engine
# CREATE TABLE DWH.fac_compras (
#     id_compra       INT AUTO_INCREMENT PRIMARY KEY,
#     id_fecha        INT NOT NULL,
#     CodProducto     NVARCHAR(50) NOT NULL,
#     CodSucursal     NVARCHAR(50) NOT NULL,
#     CodProveedor    NVARCHAR(50) NOT NULL,
#     unidades        INT NOT NULL,
#     costoUnitario   DECIMAL(10,2),
#     FOREIGN KEY (id_fecha)     REFERENCES dim_fecha(id_fecha),
#     FOREIGN KEY (CodProducto)  REFERENCES dim_producto(CodProducto),
#     FOREIGN KEY (CodSucursal)  REFERENCES dim_sucursal(CodSucursal),
#     FOREIGN KEY (CodProveedor) REFERENCES dim_proveedor(CodProveedor)
# );
#
# 2025-12-12 16:54:40,749 INFO sqlalchemy.engine.Engine [generated in 0.00293s] {}
# 2025-12-12 16:54:40,882 INFO sqlalchemy.engine.Engine COMMIT
# Error al ejecutar DDL: name 'false' is not defined
